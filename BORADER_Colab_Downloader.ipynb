# %% [markdown]
# # 🎥 BORADER Video Downloader - Google Colab Version
#
# Download videos from YouTube, TikTok, Instagram, and 1000+ sites directly in Google Colab!
#
# **✅ Works for ALL YouTube videos** - No authentication required!
#
# ---

# %% [markdown]
# ## 🚀 Quick Setup
#
# Run the cell below to install yt-dlp and download the downloader script:

# %%
# Install yt-dlp
# !pip install yt-dlp

# Download the main downloader script
# !wget -q https://raw.githubusercontent.com/bora2025/borader-downloader/main/main.py

# Create downloads directory
# !mkdir -p downloads

print("✅ Setup complete! Ready to download videos.")

# %% [markdown]
# ## 📥 Download Videos
#
# Replace `YOUR_VIDEO_URL` with your video URL and run the cell below:

# %%
# Replace YOUR_VIDEO_URL with your actual video URL
video_url = "YOUR_VIDEO_URL"  # Example: "https://www.youtube.com/watch?v=dQw4w9WgXcQ"

if video_url == "YOUR_VIDEO_URL":
    print("❌ Please replace YOUR_VIDEO_URL with your actual video URL!")
else:
    # Download the video
    # !python main.py "$video_url" --output downloads
    print(f"\n✅ Download completed! Check the 'downloads' folder on the left sidebar.")

# %% [markdown]
# ## 📁 Download Files to Your Computer
#
# After downloading, you can download the files to your computer:

# %%
# List downloaded files
# !ls -la downloads/

# Download to your computer (uncomment and run)
# from google.colab import files
# files.download('downloads/YOUR_FILE_NAME.mp4')

# %% [markdown]
# ## 💡 Tips
#
# - **Supported sites**: YouTube, TikTok, Instagram, Twitter, and 1000+ more
# - **File location**: Videos are saved in the `downloads/` folder
# - **File format**: MP4 for maximum compatibility
# - **Quality**: Downloads the best available quality
#
# ## 🔧 Advanced Usage
#
# For custom output directory:
# ```python
# !python main.py "VIDEO_URL" --output my_videos
# ```
#
# ---
#
# **Made with ❤️ by BORADER**
